# %%
from langchain_community.llms import LlamaCpp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from langchain_community.llms import LlamaCpp
#
# ModuleNotFoundError: No module named 'langchain_community'

# %% [markdown]
# Link: https://python.langchain.com/v0.1/docs/use_cases/question_answering/local_retrieval_qa/#llama2
#
# LLAMA model downloaded via LM Studio

# %%
n_gpu_layers = 1  # Metal set to 1 is enough.
n_batch = 512  # Should be between 1 and n_ctx, consider the amount of RAM of your Apple Silicon Chip.

# Make sure the model path is correct for your system!
llm = LlamaCpp(
    model_path="/Users/mauricioribeiro/.cache/lm-studio/models/mlx-community/Llama-3.2-3B-Instruct-4bit",
    n_gpu_layers=n_gpu_layers,
    n_batch=n_batch,
    n_ctx=2048,
    f16_kv=True,  # MUST set to True, otherwise you will run into problem after a couple of calls
    verbose=True,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 n_batch = 512  # Should be between 1 and n_ctx, consider the amount of RAM of your Apple Silicon Chip.
#       4 # Make sure the model path is correct for your system!
# ----> 5 llm = LlamaCpp(
#       6     model_path="/Users/mauricioribeiro/.cache/lm-studio/models/mlx-community/Llama-3.2-3B-Instruct-4bit",
#       7     n_gpu_layers=n_gpu_layers,
#       8     n_batch=n_batch,
#       9     n_ctx=2048,
#      10     f16_kv=True,  # MUST set to True, otherwise you will run into problem after a couple of calls
#      11     verbose=True,
#      12 )
#
# NameError: name 'LlamaCpp' is not defined
